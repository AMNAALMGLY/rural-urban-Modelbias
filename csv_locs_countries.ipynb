# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Script-for-creating-the-loc_dict" data-toc-modified-id="Script-for-creating-the-loc_dict-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Script for creating the loc_dict</a></span></li></ul></div>

# %% [markdown]
# ## Script for creating the loc_dict
#
# The `loc_dict` maps location tuples `(lat, lon)` to survey data.
#
# ```
# {
#     (lat, lon) : {
#         'cluster': int64,
#         'wealthpooled': float64,
#         'wealth': float64,
#         'year': int64,
#         'country': str,
#         'country_year': str,
#         'households': int64,
#         'urban': int64
#     }
# }
# ```
#
# - `lat` and `lon` have type `np.float32`
# - `country` and `country_year` are all lowercase, with underscores `_` in place of spaces
# - `country_year` has an underscore `_` separating the country name from the year

# %%
import os
import pandas as pd
import numpy as np
from collections import defaultdict
from pprint import pprint

csv_path = '/atlas/group/poverty_data/surveys/wealthpooled_chris/original_survey_file/AllCountryWealthIndex.csv'
df = pd.read_csv(csv_path, float_precision='high')

df.rename(columns={'LATNUM': 'lat', 'LONGNUM': 'lon', 'URBAN_RURA': 'urban'}, inplace=True)

# drop all rows that have NaN in any of our desired columns
notna_cols = ['svyid', 'lat', 'lon', 'cluster', 'wealthpooled', 'wealth', 'year', 'country', 'households', 'urban']
df = df.dropna(axis=0, subset=notna_cols, how='any')

# convert 'urban' column from string to int: 'U' (urban) => 1, 'R' (rural) => 0
df['urban'] = df['urban'].map({'U': 1, 'R': 0})

df = df[~df['svyid'].str.endswith('a')]

df
# Out:
#        cluster   svyid  wealthpooled  wealthpooled5country    wealth iso3  \
# 0            1  AO2011      2.595618              2.375126  1.713497  AGO
# 1            2  AO2011      2.209620              1.999398  1.545335  AGO
# 2            3  AO2011      0.906469              0.677429  0.631730  AGO
# 3            4  AO2011      1.105359              0.890651  0.826273  AGO
# 4            5  AO2011      1.879344              1.662076  1.293282  AGO
# 5            6  AO2011      1.749317              1.536088  1.153628  AGO
# 6            7  AO2011      0.182361             -0.025417  0.072375  AGO
# 7            8  AO2011      0.691216              0.478429  0.348369  AGO
# 8            9  AO2011      0.527798              0.357196  0.341848  AGO
# 9           10  AO2011      0.891160              0.692653  0.743994  AGO
# 10          11  AO2011      0.936777              0.726025  0.666628  AGO
# 11          12  AO2011     -0.052652             -0.267560  0.033149  AGO
# 12          13  AO2011     -0.073470             -0.328117 -0.123748  AGO
# 13          14  AO2011      0.721673              0.480767  0.361996  AGO
# 14          15  AO2011     -0.117269             -0.380730 -0.168474  AGO
# 15          16  AO2011      0.381619              0.142947  0.299032  AGO
# 16          17  AO2011     -1.142210             -1.404703 -1.101275  AGO
# 17          18  AO2011     -0.852930             -1.134224 -0.847475  AGO
# 18          19  AO2011     -0.463503             -0.728282 -0.498751  AGO
# 19          20  AO2011     -1.057123             -1.320920 -1.059320  AGO
# 20          21  AO2011     -1.063374             -1.311176 -0.801240  AGO
# 21          22  AO2011      0.409534              0.191272  0.242953  AGO
# 22          23  AO2011     -0.906611             -1.180653 -0.911823  AGO
# 23          24  AO2011     -1.178294             -1.438758 -1.129993  AGO
# 7       AO5  2011    AO    Angola   Middle Africa     24          30
# 8       AO5  2011    AO    Angola   Middle Africa     24          36
# 9       AO5  2011    AO    Angola   Middle Africa     24          35
# 10      AO5  2011    AO    Angola   Middle Africa     24          33
# 11      AO5  2011    AO    Angola   Middle Africa     24          34
# 12      AO5  2011    AO    Angola   Middle Africa     24          36
# 13      AO5  2011    AO    Angola   Middle Africa     24          37
# 14      AO5  2011    AO    Angola   Middle Africa     24          36
# 15      AO5  2011    AO    Angola   Middle Africa     24          37
# 16      AO5  2011    AO    Angola   Middle Africa     24          37
# 17      AO5  2011    AO    Angola   Middle Africa     24          37
# 18      AO5  2011    AO    Angola   Middle Africa     24          37
# 19      AO5  2011    AO    Angola   Middle Africa     24          37
# 20      AO5  2011    AO    Angola   Middle Africa     24          37
# 21      AO5  2011    AO    Angola   Middle Africa     24          37
# 22      AO5  2011    AO    Angola   Middle Africa     24          33
# 23      AO5  2011    AO    Angola   Middle Africa     24          23
# 24      AO5  2011    AO    Angola   Middle Africa     24          28
# 25      AO5  2011    AO    Angola   Middle Africa     24          26
# 28      AO5  2011    AO    Angola   Middle Africa     24          37
# 29      AO5  2011    AO    Angola   Middle Africa     24          33
# 30      AO5  2011    AO    Angola   Middle Africa     24          37
# 31      AO5  2011    AO    Angola   Middle Africa     24          37
# ...     ...   ...   ...       ...             ...    ...         ...
# 35205   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35206   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35207   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35208   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35209   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35210   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          21
# 35211   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35212   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35213   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          25
# 35214   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35215   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35216   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35217   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          23
# 35218   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          26
# 35219   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35220   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35221   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35222   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          27
# 35223   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35224   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          24
# 35225   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          27
# 35226   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          25
# 35227   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          22
# 35228   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          27
# 35229   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          27
# 35230   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          24
# 35231   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          25
# 35232   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
# 35233   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          25
# 35234   ZW7  2015    ZW  Zimbabwe  Eastern Africa    716          28
#
#              lat        lon  urban
# 0     -12.350257  13.534922      1
# 1     -12.360865  13.551494      1
# 2     -12.613421  13.413085      1
# 3     -12.581454  13.397711      1
# 4     -12.578135  13.418748      1
# 5     -12.575305  13.408575      1
# 6     -11.188879  13.838995      1
# 7     -11.200050  13.832946      1
# 8      -8.593237  13.643248      1
# 9      -8.583901  13.664315      1
# 10    -12.752814  15.742476      1
# 11    -12.782553  15.754300      1
# 12    -12.600115  13.200098      0
# 13    -12.594752  13.202681      0
# 14    -12.426923  13.554357      0
# 15    -12.426737  13.558511      0
# 16    -13.434386  14.269446      0
# 17    -13.465144  14.278094      0
# 18    -12.344750  14.773096      1
# 19    -12.371371  14.753342      0
# 20    -10.871302  14.353967      0
# 21    -10.858034  14.358820      0
# 22    -10.419603  13.970724      0
# 23    -10.390981  13.984454      0
# 24    -11.537386  14.726956      0
# 25    -11.517536  14.754720      0
# 28     -9.096796  13.646400      0
# 29     -9.172912  13.648187      0
# 30     -8.159112  14.469092      0
# 31     -8.159944  14.460016      0
# ...          ...        ...    ...
# 35205 -22.127690  30.765533      0
# 35206 -16.822456  29.694618      1
# 35207 -18.604266  32.087744      0
# 35208 -20.190443  28.518083      1
# 35209 -20.099344  30.815886      1
# 35210 -17.106132  32.740930      0
# 35211 -17.770153  30.236368      0
# 35212 -20.191504  28.541807      1
# 35213 -18.956835  28.873671      0
# 35214 -17.806438  32.001973      0
# 35215 -20.171571  28.506735      1
# 35216 -19.939451  31.822948      0
# 35217 -19.851952  28.240478      0
# 35218 -22.191800  30.002585      1
# 35219 -20.940628  29.015198      1
# 35220 -22.126261  29.639609      0
# 35221 -21.071077  28.599114      0
# 35222 -20.461442  32.636478      0
# 35223 -18.539668  31.318977      0
# 35224 -17.878083  31.033349      1
# 35225 -20.440976  31.075466      0
# 35226 -20.144304  28.568426      1
# 35227 -17.693933  31.121826      1
# 35228 -17.929422  30.997536      0
# 35229 -17.166506  29.718371      0
# 35230 -17.915288  31.156115      1
# 35231 -18.379501  31.872287      0
# 35232 -16.660612  29.850649      0
# 35233 -17.914251  30.956975      1
# 35234 -17.859114  31.797626      0
#
# [26607 rows x 16 columns]

# %%
df.loc[:, 'lat'] = df.loc[:, 'lat'].astype(np.float32)
df.loc[:, 'lon'] = df.loc[:, 'lon'].astype(np.float32)
print(df.dtypes)
print(len(df))
num_dup_locs = np.sum(df.duplicated(subset=['lat', 'lon']))
print(num_dup_locs)
# Out:
# cluster                   int64
# svyid                    object
# wealthpooled            float64
# wealthpooled5country    float64
# wealth                  float64
# iso3                     object
# hv000                    object
# year                      int64
# cname                    object
# country                  object
# region                   object
# iso3n                     int64
# households                int64
# lat                     float32
# lon                     float32
# urban                     int64
# dtype: object
# 26607
# 0

# %%
loc_dict = {}
survey_ids = set(df["svyid"])

output_cols = ['cluster', 'wealthpooled', 'wealth', 'year', 'country', 'country_year', 'households', 'urban']

def svyid_to_year(x):
    digits = [str(i) for i in range(10)]
    return int("".join([c for c in x if c in digits]))

for i, survey_id in enumerate(survey_ids):
    survey_data = df.loc[df['svyid'] == survey_id].copy()

    country = survey_data["country"].iloc[0]
    year = svyid_to_year(survey_id)
    assert np.all(survey_data["country"] == country)

    # within the country name, replace spaces (" ") and apostrophes ("'") with underscores ("_")
    country = country.lower().replace(" ", "_").replace("'", "_")
    country_year = "{}_{}".format(country, year)
    
    survey_data.loc[:, 'country'] = country
    survey_data.loc[:, 'country_year'] = country_year

    if survey_id[-1] == "a":
        print("{} is AIS, skipping".format(survey_id))
        continue

    num_dup_locs = np.sum(survey_data.duplicated(subset=['lat', 'lon']))
    print('{}, {}, num_dup_locs: {}'.format(country, year, num_dup_locs))
    assert num_dup_locs == 0

    survey_data.set_index(['lat', 'lon'], inplace=True, verify_integrity=True)
    curr_loc_dict = survey_data[output_cols].to_dict('index')
    
    for (lat64, lon64), v in curr_loc_dict.items():
        loc = (np.float32(lat64), np.float32(lon64))
        if loc in loc_dict:
            raise ValueError("unexpected duplicate loc")
        else:
            loc_dict[loc] = v
# Out:
# malawi, 2012, num_dup_locs: 0
# tanzania, 2010, num_dup_locs: 0
# ghana, 2008, num_dup_locs: 0
# nigeria, 2015, num_dup_locs: 0
# kenya, 2014, num_dup_locs: 0
# zimbabwe, 2010, num_dup_locs: 0
# senegal, 2010, num_dup_locs: 0
# lesotho, 2009, num_dup_locs: 0
# mozambique, 2009, num_dup_locs: 0
# uganda, 2009, num_dup_locs: 0
# tanzania, 2007, num_dup_locs: 0
# mali, 2012, num_dup_locs: 0
# lesotho, 2014, num_dup_locs: 0
# uganda, 2014, num_dup_locs: 0
# nigeria, 2013, num_dup_locs: 0
# uganda, 2011, num_dup_locs: 0
# malawi, 2015, num_dup_locs: 0
# tanzania, 2004, num_dup_locs: 0
# democratic_republic_of_congo, 2007, num_dup_locs: 0
# senegal, 2012, num_dup_locs: 0
# burkina_faso, 2014, num_dup_locs: 0
# kenya, 2015, num_dup_locs: 0
# togo, 2013, num_dup_locs: 0
# guinea, 2012, num_dup_locs: 0
# mali, 2015, num_dup_locs: 0
# tanzania, 2011, num_dup_locs: 0
# kenya, 2008, num_dup_locs: 0
# benin, 2012, num_dup_locs: 0
# malawi, 2014, num_dup_locs: 0
# ghana, 2014, num_dup_locs: 0
# mozambique, 2011, num_dup_locs: 0
# sierra_leone, 2013, num_dup_locs: 0
# zimbabwe, 2005, num_dup_locs: 0
# ethiopia, 2016, num_dup_locs: 0
# mali, 2006, num_dup_locs: 0
# rwanda, 2010, num_dup_locs: 0
# sierra_leone, 2008, num_dup_locs: 0
# democratic_republic_of_congo, 2013, num_dup_locs: 0
# nigeria, 2010, num_dup_locs: 0
# zambia, 2007, num_dup_locs: 0
# uganda, 2006, num_dup_locs: 0
# zambia, 2013, num_dup_locs: 0
# cameroon, 2011, num_dup_locs: 0
# zimbabwe, 2015, num_dup_locs: 0
# nigeria, 2003, num_dup_locs: 0
# burkina_faso, 2010, num_dup_locs: 0
# cameroon, 2004, num_dup_locs: 0
# ghana, 2016, num_dup_locs: 0
# nigeria, 2008, num_dup_locs: 0
# kenya, 2003, num_dup_locs: 0
# senegal, 2008, num_dup_locs: 0
# ethiopia, 2005, num_dup_locs: 0
# ethiopia, 2010, num_dup_locs: 0
# angola, 2011, num_dup_locs: 0
# swaziland, 2006, num_dup_locs: 0
# malawi, 2010, num_dup_locs: 0
# rwanda, 2014, num_dup_locs: 0
# angola, 2015, num_dup_locs: 0
# tanzania, 2015, num_dup_locs: 0
# cote_d_ivoire, 2012, num_dup_locs: 0

# %%
import sys
sys.getsizeof(loc_dict)
# Out:
# 1310816

# %%
import pickle
loc_dict_path = '/atlas/group/poverty_data/surveys/wealthpooled_chris/loc_dict.pkl'
with open(loc_dict_path, 'wb') as f:
    pickle.dump(loc_dict, f)
